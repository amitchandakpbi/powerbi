# %%
import pandas as pd
excel_file_path = "https://github.com/amitchandakpbi/powerbi/raw/main/Sales%20Data%20for%20Fabric.xlsx"

# Use pandas to read the Excel file
df_sales = pd.read_excel(excel_file_path, sheet_name="Sales")
df_customer = pd.read_excel(excel_file_path, sheet_name="Customer")
df_geo = pd.read_excel(excel_file_path, sheet_name="Geography")
df_item = pd.read_excel(excel_file_path, sheet_name="Item")
# Out:
# StatementMeta(, 98799f1c-266c-4f6f-9bde-49b74a449a53, 3, Finished, Available, Finished, False)

# %%
print(df_sales.head())
# Out:
# StatementMeta(, 98799f1c-266c-4f6f-9bde-49b74a449a53, 5, Finished, Available, Finished, False)
#    OrderNo  ItemID  SalesDate DeilveryDate  CustomerId  CityId  Qty  Price  \
# 0    20277      37 2020-10-03   2020-10-06        2691      26    1    233
# 1    22328      23 2020-10-03   2020-10-07        6085      61    1     60
# 2    22784      53 2020-10-03   2020-10-09        3562      19    1    333
# 3    25881      14 2020-10-03   2020-10-09         338      52    2    753
# 4    26399      52 2020-10-03   2020-10-13        4995      51    2     53
#
#    cost  DiscountPercent
# 0   172               12
# 1    54                9
# 2   259                5
# 3   301               39
# 4    45               28

# %%
display(df_sales)
# Out:
# StatementMeta(, 98799f1c-266c-4f6f-9bde-49b74a449a53, 7, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 6dbd3688-8d2a-41ab-a131-4c614370d158)

# %%
sales = spark.createDataFrame(df_sales)
customer = spark.createDataFrame(df_customer)
geography = spark.createDataFrame(df_geo)
item = spark.createDataFrame(df_item)
# Out:
# StatementMeta(, 98799f1c-266c-4f6f-9bde-49b74a449a53, 8, Finished, Available, Finished, False)

# %%
display(sales)
# Out:
# StatementMeta(, 98799f1c-266c-4f6f-9bde-49b74a449a53, 9, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 0cdbaeb8-5d20-4084-a12c-d7087ddcb147)

# %%
# Describe the DataFrames
sales.describe().show()
geography.describe().show()
customer.describe().show()
item.describe().show()
# Out:
# StatementMeta(, 98799f1c-266c-4f6f-9bde-49b74a449a53, 10, Finished, Available, Finished, False)
# +-------+-----------------+------------------+-----------------+------------------+------------------+------------------+------------------+------------------+
# |summary|          OrderNo|            ItemID|       CustomerId|            CityId|               Qty|             Price|              cost|   DiscountPercent|
# +-------+-----------------+------------------+-----------------+------------------+------------------+------------------+------------------+------------------+
# |  count|            30000|             30000|            30000|             30000|             30000|             30000|             30000|             30000|
# |   mean|          15000.5|           23.8998|2586.925166666667|           47.0278|1.6637666666666666|207.29673333333332|138.50326666666666|           23.0316|
# | stddev|8660.398374208884|12.967396233329536|1601.835989394005|28.381839465646248|0.6669297604688733|322.94307014840973| 199.5885266625516|12.995515799216903|
# |    min|                1|                 1|                1|                 1|                 1|                40|                36|                 1|
# |    max|            30000|                55|             6501|               100|                 3|              1733|              1299|                45|
# +-------+-----------------+------------------+-----------------+------------------+------------------+------------------+------------------+------------------+
#
# +-------+------------------+---------------+---------+
# |summary|            CityId|           City|    State|
# +-------+------------------+---------------+---------+
# |  count|               100|            100|      100|
# |   mean|              50.5|           NULL|     NULL|
# | stddev|29.011491975882016|           NULL|     NULL|
# |    min|                 1|    Albuquerque|   Alaska|
# |    max|               100|Winstonâ€“Salem|Wisconsin|
# +-------+------------------+---------------+---------+
#
# +-------+------------------+-----------------+---------------+---------+------------+
# |summary|        CustomerId|              Age|           City|    State|        Name|
# +-------+------------------+-----------------+---------------+---------+------------+
# |  count|              6138|             6138|           6138|     6138|        6138|
# |   mean|  3116.08211143695|34.43189964157706|           NULL|     NULL|        NULL|
# | stddev|1831.4120792734825|8.169102797527293|           NULL|     NULL|        NULL|
# |    min|                 1|               20|    Albuquerque|   Alaska|  Customer 1|
# |    max|              6501|               70|Winstonâ€“Salem|Wisconsin|Customer 999|
# +-------+------------------+-----------------+---------------+---------+------------+
#
# +-------+------------------+------+------------------+------------------+------------------+-------+----------+-----------+
# |summary|            ItemId|  Name|           BrandId|        CategoryId|     SubCategoryId|  Brand|  Category|SubCategory|
# +-------+------------------+------+------------------+------------------+------------------+-------+----------+-----------+
# |  count|                55|    55|                55|                55|                55|     55|        55|         55|
# |   mean|              28.0|  NULL| 7.618181818181818|2.6363636363636362|10.381818181818181|   NULL|      NULL|       NULL|
# | stddev|16.020819787597222|  NULL|3.5719634039170334|1.2526067096353786| 5.955050483633725|   NULL|      NULL|       NULL|
# |    min|                 1|Item 1|                 1|                 1|                 1|Brand 1|Category 1|  Sub Cat 1|
# |    max|                55|Item 9|                13|                 5|                21|Brand 9|Category 5|  Sub Cat 8|
# +-------+------------------+------+------------------+------------------+------------------+-------+----------+-----------+

# %%
display(geography.summary())
display(sales.summary())
# Out:
# StatementMeta(, 98799f1c-266c-4f6f-9bde-49b74a449a53, 11, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 87307f94-41d2-49e6-90fa-daf405ddf198)
# SynapseWidget(Synapse.DataFrame, ef66062f-90af-4c11-9580-d16147c94b6a)

# %%
df_customer_1_to_60 = customer.select("CustomerId").filter(customer.CustomerId.between(1, 60))
df_customer_40_to_100  = customer.select("CustomerId").filter(customer.CustomerId.between(40, 100))

# %%
sales_filter = sales.filter(sales.CustomerId.between(59, 62))
customer_filter = customer.filter(customer.CustomerId.between(50, 60))
# Out:
# StatementMeta(, 98799f1c-266c-4f6f-9bde-49b74a449a53, 24, Finished, Available, Finished, False)

# %%
#inner
inner_join_df = sales_filter.join(customer_filter, "CustomerId", "inner")
print("Inner Join DataFrame:")
display(inner_join_df)
# Out:
# StatementMeta(, 98799f1c-266c-4f6f-9bde-49b74a449a53, 45, Finished, Available, Finished, False)
# Inner Join DataFrame:
# SynapseWidget(Synapse.DataFrame, 3e3b5f4b-6911-4c8f-be2b-3926d6b02370)

# %%
#left
left_join_df = sales_filter.join(customer_filter, "CustomerId", "left")
print("Inner Join DataFrame:")
display(left_join_df)
# Out:
# StatementMeta(, 98799f1c-266c-4f6f-9bde-49b74a449a53, 46, Finished, Available, Finished, False)
# Inner Join DataFrame:
# SynapseWidget(Synapse.DataFrame, 50f9813e-6448-4bf5-9560-7ac10f8e865a)

# %%
#right
right_join_df = sales_filter.join(customer_filter, "CustomerId", "right")
print("Inner Join DataFrame:")
display(right_join_df)
# Out:
# StatementMeta(, 98799f1c-266c-4f6f-9bde-49b74a449a53, 47, Finished, Available, Finished, False)
# Inner Join DataFrame:
# SynapseWidget(Synapse.DataFrame, 28d1b585-7f34-483f-8ba4-fb27bf4de5d0)

# %%
#full
full_join_df = sales_filter.join(customer_filter, "CustomerId", "full")
print("Inner Join DataFrame:")
display(full_join_df)
# Out:
# StatementMeta(, 98799f1c-266c-4f6f-9bde-49b74a449a53, 48, Finished, Available, Finished, False)
# Inner Join DataFrame:
# SynapseWidget(Synapse.DataFrame, 98e026dc-000a-43c3-8b99-84f14423b7bf)

# %%
#leftanti
leftanti_join_df = sales_filter.join(customer_filter, "CustomerId", "anti")
print("leftanti Join DataFrame:")
display(leftanti_join_df)
# Out:
# StatementMeta(, 98799f1c-266c-4f6f-9bde-49b74a449a53, 50, Finished, Available, Finished, False)
# leftanti Join DataFrame:
# SynapseWidget(Synapse.DataFrame, 24d570e4-da11-4139-85a0-55588d3d432b)

# %%
#leftanti
leftanti_join_df = customer_filter.join(sales_filter, "CustomerId", "anti")
print("leftanti Join DataFrame:")
display(leftanti_join_df)
# Out:
# StatementMeta(, 98799f1c-266c-4f6f-9bde-49b74a449a53, 52, Finished, Available, Finished, False)
# leftanti Join DataFrame:
# SynapseWidget(Synapse.DataFrame, 898d653d-7b27-4493-a754-e60077a79221)

# %%
customer = customer.drop('State', 'City')
display(customer)
# Out:
# StatementMeta(, 98799f1c-266c-4f6f-9bde-49b74a449a53, 53, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 144c026b-0a94-4221-b3e3-cef8d4bd4d9f)

# %%
sales_customer = sales.join(customer, "CustomerId")
sales_customer_geo = sales_customer.join(geography, "CityId")
# Perform the join operation
sales_all = sales_customer_geo.join(item, sales.ItemID == item.ItemId, "inner")

# Show the result of the join
print("Inner Join DataFrame:")
display(sales_all)
# Out:
# StatementMeta(, 98799f1c-266c-4f6f-9bde-49b74a449a53, 55, Finished, Available, Finished, False)
# Inner Join DataFrame:
# SynapseWidget(Synapse.DataFrame, 1805232c-4197-4a37-9f65-f89ef52e94d7)

# %%
from pyspark.sql.functions import col, expr

# Adding calculated columns
sales_all = sales_all.withColumn("Gross", col("Qty") * col("Price"))
sales_all = sales_all.withColumn("COGS", col("Qty") * col("Cost"))
sales_all = sales_all.withColumn("Discount", col("Qty") * col("Price") * col("DiscountPercent")/100)

# Display the DataFrame with new columns
display(sales_all)
# Out:
# StatementMeta(, 98799f1c-266c-4f6f-9bde-49b74a449a53, 60, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 1ad7cc3c-dfa0-4749-b5f0-62438ae943c5)

# %%
# Grouping by City and State
grouped_city_state = sales_all.groupBy("City", "State").agg(
    expr("sum(Gross) as TotalGross"),
    expr("sum(COGS) as TotalCOGS"),
    expr("sum(Discount) as TotalDiscount")
)
grouped_city_state.show()
# Out:
# StatementMeta(, 98799f1c-266c-4f6f-9bde-49b74a449a53, 62, Finished, Available, Finished, False)
# +-----------+------------+----------+---------+------------------+
# |       City|       State|TotalGross|TotalCOGS|     TotalDiscount|
# +-----------+------------+----------+---------+------------------+
# | Cincinnati|        Ohio|     65548|    45555|13502.250000000002|
# |     Austin|       Texas|    115566|    76911|27361.010000000002|
# | Pittsburgh|Pennsylvania|     89223|    59528|          23029.92|
# |   Columbus|        Ohio|     85842|    57465|           20322.9|
# |     Tucson|     Arizona|     94897|    62197|           18655.2|
# |   San Jose|  California|    107614|    73180|26049.100000000006|
# |Minneapolis|   Minnesota|     84282|    54374|19944.170000000002|
# |   Chandler|     Arizona|     54105|    36630|          12822.13|
# |     Laredo|       Texas|     96928|    61701|          21211.57|
# |    Garland|       Texas|     77301|    50063|          17282.97|
# |    Fremont|  California|     85654|    57007|          22951.71|
# |    Detroit|    Michigan|     98973|    67748|           23379.1|
# | Long Beach|  California|    145006|    96550|          35017.24|
# |  Las Vegas|      Nevada|    112437|    74856|27791.839999999997|
# |    Orlando|     Florida|     98157|    65048|          26266.27|
# |      Tulsa|    Oklahoma|    140088|    93958|32410.219999999998|
# |     Irvine|  California|     57105|    38783|11898.470000000001|
# |   Portland|      Oregon|    126208|    82344|28127.109999999993|
# | Saint Paul|   Minnesota|    116202|    76285|23425.449999999997|
# |   New York|    New York|    129860|    86492|          32322.33|
# +-----------+------------+----------+---------+------------------+
# only showing top 20 rows

# %%
# Grouping by Brand and Category
grouped_brand_category = sales_all.groupBy("Brand", "Category").agg(
    expr("sum(Gross) as TotalGross"),
    expr("sum(COGS) as TotalCOGS"),
    expr("avg(Qty) as TotalQty"),
    expr("sum(Discount) as TotalDiscount")
)
grouped_brand_category.show()
# Out:
# StatementMeta(, 98799f1c-266c-4f6f-9bde-49b74a449a53, 65, Finished, Available, Finished, False)
# +--------+----------+----------+---------+------------------+------------------+
# |   Brand|  Category|TotalGross|TotalCOGS|          TotalQty|     TotalDiscount|
# +--------+----------+----------+---------+------------------+------------------+
# | Brand 8|Category 2|    886826|   589234|1.6801215277777777|         206629.12|
# | Brand 3|Category 5|    181600|   125786|1.7830188679245282|44616.759999999995|
# | Brand 4|Category 3|     54082|    36555|1.4672897196261683|12688.869999999997|
# | Brand 4|Category 2|     53334|    35986|1.5439330543933054|12325.920000000002|
# |Brand 12|Category 2|    188825|   127956|1.5107142857142857| 43472.84000000001|
# | Brand 2|Category 2|    250798|   169413| 1.690694626474443| 59263.81999999999|
# |Brand 11|Category 4|    360074|   242158|1.6500453309156844|          86238.37|
# | Brand 1|Category 1|    293800|   191874|1.6830188679245284| 67580.90999999999|
# | Brand 5|Category 2|    324370|   215318|1.5877862595419847|           71071.5|
# | Brand 6|Category 1|    270517|   180777|1.6353077816492452| 62035.46000000001|
# | Brand 5|Category 3|     66804|    44226| 1.523404255319149|          16729.96|
# | Brand 9|Category 5|     59568|    39960|1.5146443514644352|12881.490000000002|
# |Brand 11|Category 3|    357756|   238716| 1.646061814556331|          80828.26|
# | Brand 5|Category 1|    295566|   200740|1.6851851851851851|           72614.4|
# |Brand 10|Category 1|    214515|   142816|1.6911357340720221| 46879.29000000001|
# | Brand 9|Category 2|    850790|   567259| 1.633711507293355|         193622.23|
# |Brand 11|Category 1|    274173|   180751|1.6714456391875747|62231.049999999996|
# | Brand 3|Category 4|    149312|   101249| 1.777327935222672|           32877.4|
# | Brand 2|Category 4|    585593|   396983|1.6542553191489362|141987.25000000003|
# | Brand 7|Category 4|    258465|   171328|1.7100494233937398|54838.459999999985|
# +--------+----------+----------+---------+------------------+------------------+
# only showing top 20 rows

# %%
sales.write.format("delta").saveAsTable("dbo.sales_delta")
# Out:
# StatementMeta(, 98799f1c-266c-4f6f-9bde-49b74a449a53, 67, Finished, Available, Finished, False)

# %%
geography.write.format("delta").mode("overwrite").save("Tables/dbo/geography")
# Out:
# StatementMeta(, 98799f1c-266c-4f6f-9bde-49b74a449a53, 68, Finished, Available, Finished, False)

# %%
df = spark.sql("SELECT * FROM LH_Sales.dbo.sales_delta LIMIT 1000")
display(df)
# Out:
# StatementMeta(, 98799f1c-266c-4f6f-9bde-49b74a449a53, 69, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 8acd1a60-70c3-4069-93e9-b0287079dd17)

# %%
df = spark.sql("SELECT * FROM LH_Sales.dbo.geography LIMIT 1000")
display(df)

# %%
display(spark.read.table("LH_Sales.dbo.sales_delta "))
# Out:
# StatementMeta(, 98799f1c-266c-4f6f-9bde-49b74a449a53, 72, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 29b171ad-5b85-4dae-8403-be6551bbea94)

# %%
from delta.tables import DeltaTable

delta_table = DeltaTable.forName(spark, "dbo.sales_delta")

delta_table.update(
    condition="Qty = 2",
    set={"Qty": "4"}
)
# Out:
# StatementMeta(, 98799f1c-266c-4f6f-9bde-49b74a449a53, 73, Finished, Available, Finished, False)

# %%
display(spark.read.table("LH_Sales.dbo.sales_delta "))
# Out:
# StatementMeta(, 98799f1c-266c-4f6f-9bde-49b74a449a53, 74, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, aec43750-663e-4251-991c-b8602e926efe)

# %%
display(delta_table.history())
# Out:
# StatementMeta(, 98799f1c-266c-4f6f-9bde-49b74a449a53, 75, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, ce1ca022-01a1-42a1-8232-d17a1e7c740c)

# %%
delta_table.delete("Qty = 3")
# Out:
# StatementMeta(, 98799f1c-266c-4f6f-9bde-49b74a449a53, 76, Finished, Available, Finished, False)

# %%
from delta.tables import DeltaTable

DeltaTable.forName(spark, "sales_delta").history().show(truncate=False)
# Out:
# StatementMeta(, 98799f1c-266c-4f6f-9bde-49b74a449a53, 80, Finished, Available, Finished, False)
# +-------+-----------------------+------+--------+----------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----+--------+---------+-----------+--------------+-------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------+
# |version|timestamp              |userId|userName|operation             |operationParameters                                                                                                                                                     |job |notebook|clusterId|readVersion|isolationLevel|isBlindAppend|operationMetrics                                                                                                                                                                                                                                                                                                                          |userMetadata|engineInfo                                                   |
# +-------+-----------------------+------+--------+----------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----+--------+---------+-----------+--------------+-------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------+
# |2      |2026-07-24 02:54:28.506|NULL  |NULL    |DELETE                |{predicate -> ["(Qty#6294L = 3)"]}                                                                                                                                      |NULL|NULL    |NULL     |1          |Serializable  |false        |{numRemovedFiles -> 8, numRemovedBytes -> 515998, numCopiedRows -> 26676, numDeletionVectorsAdded -> 0, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, executionTimeMs -> 1342, numDeletionVectorsUpdated -> 0, numDeletedRows -> 3324, scanTimeMs -> 749, numAddedFiles -> 8, numAddedBytes -> 465913, rewriteTimeMs -> 592}  |NULL        |Apache-Spark/3.5.5.5.4.20260403.6 Delta-Lake/3.2.1.20260427.3|
# |1      |2026-07-24 02:50:02.171|NULL  |NULL    |UPDATE                |{predicate -> ["(Qty#6294L = 2)"]}                                                                                                                                      |NULL|NULL    |NULL     |0          |Serializable  |false        |{numRemovedFiles -> 8, numRemovedBytes -> 515998, numCopiedRows -> 16735, numDeletionVectorsAdded -> 0, numDeletionVectorsRemoved -> 0, numAddedChangeFiles -> 0, executionTimeMs -> 1885, numDeletionVectorsUpdated -> 0, scanTimeMs -> 1057, numAddedFiles -> 8, numUpdatedRows -> 13265, numAddedBytes -> 515998, rewriteTimeMs -> 827}|NULL        |Apache-Spark/3.5.5.5.4.20260403.6 Delta-Lake/3.2.1.20260427.3|
# |0      |2026-07-24 02:38:06.324|NULL  |NULL    |CREATE TABLE AS SELECT|{partitionBy -> [], clusterBy -> [], description -> NULL, isManaged -> true, properties -> {"delta.stats.extended.collect":"true","delta.stats.extended.inject":"true"}}|NULL|NULL    |NULL     |NULL       |Serializable  |true         |{numFiles -> 8, numOutputRows -> 30000, numOutputBytes -> 515998}                                                                                                                                                                                                                                                                         |NULL        |Apache-Spark/3.5.5.5.4.20260403.6 Delta-Lake/3.2.1.20260427.3|
# +-------+-----------------------+------+--------+----------------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------+----+--------+---------+-----------+--------------+-------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+------------+-------------------------------------------------------------+

# %%
display(delta_table.history())
# Out:
# StatementMeta(, 98799f1c-266c-4f6f-9bde-49b74a449a53, 81, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 2137d585-33f5-415d-b495-3831d8279038)

# %%
display(spark.read.table("LH_Sales.dbo.sales_delta "))
# Out:
# StatementMeta(, 98799f1c-266c-4f6f-9bde-49b74a449a53, 78, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 467a8730-2cd6-4b4f-87b8-8229a639eb9f)

# %%
display(spark.read.option("versionAsOf", 0).table("sales_delta"))
# Out:
# StatementMeta(, 98799f1c-266c-4f6f-9bde-49b74a449a53, 79, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 47103a5d-fb3a-451c-9caf-570346b7cc7c)

# %%
delta_table.restoreToVersion(0)
# Out:
# StatementMeta(, 98799f1c-266c-4f6f-9bde-49b74a449a53, 82, Finished, Available, Finished, False)
# DataFrame[table_size_after_restore: bigint, num_of_files_after_restore: bigint, num_removed_files: bigint, num_restored_files: bigint, removed_files_size: bigint, restored_files_size: bigint]

# %%
display(delta_table.history())
# Out:
# StatementMeta(, 98799f1c-266c-4f6f-9bde-49b74a449a53, 83, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 968824d4-33b7-497e-8bb9-2204fea519ed)
