# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!

df = spark.sql("SELECT * FROM Lake01.dbo.dimension_city LIMIT 1000")
display(df)
# Out:
# StatementMeta(, 40daaad8-6c33-497a-b87e-148ae9c23525, 3, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 930e3c81-b883-4518-bf55-aba040e1f7bb)

# %%
import pandas as pd
excel_file_path = "https://github.com/amitchandakpbi/powerbi/raw/main/Sales%20Data%20for%20Fabric.xlsx"

# Use pandas to read the Excel file
df_sales = pd.read_excel(excel_file_path, sheet_name="Sales")
df_customer = pd.read_excel(excel_file_path, sheet_name="Customer")
df_geo = pd.read_excel(excel_file_path, sheet_name="Geography")
df_item = pd.read_excel(excel_file_path, sheet_name="Item")
# Out:
# StatementMeta(, 40daaad8-6c33-497a-b87e-148ae9c23525, 4, Finished, Available, Finished)

# %%
print(df_sales.head())
# Out:
# StatementMeta(, 40daaad8-6c33-497a-b87e-148ae9c23525, 5, Finished, Available, Finished)
#    OrderNo  ItemID  SalesDate DeilveryDate  CustomerId  CityId  Qty  Price  \
# 0    20277      37 2020-10-03   2020-10-06        2691      26    1    233
# 1    22328      23 2020-10-03   2020-10-07        6085      61    1     60
# 2    22784      53 2020-10-03   2020-10-09        3562      19    1    333
# 3    25881      14 2020-10-03   2020-10-09         338      52    2    753
# 4    26399      52 2020-10-03   2020-10-13        4995      51    2     53
#
#    cost  DiscountPercent
# 0   172               12
# 1    54                9
# 2   259                5
# 3   301               39
# 4    45               28

# %%
# Code generated by Data Wrangler for pandas DataFrame

def clean_data(df_sales):
    # Filter rows based on column: 'CityId'
    df_sales = df_sales[df_sales['CityId'] == 1]
    return df_sales

df_sales_clean = clean_data(df_sales.copy())
display(df_sales_clean)
# Out:
# StatementMeta(, 40daaad8-6c33-497a-b87e-148ae9c23525, 22, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 30819434-df22-414b-a4f6-8813d3438f3e)

# %%
display(df_sales)
# Out:
# StatementMeta(, 40daaad8-6c33-497a-b87e-148ae9c23525, 23, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 9c0a211e-01cb-459b-88fd-9fda38d90249)

# %%
sales = spark.createDataFrame(df_sales)
customer = spark.createDataFrame(df_customer)
geography = spark.createDataFrame(df_geo)
item = spark.createDataFrame(df_item)
# Out:
# StatementMeta(, 40daaad8-6c33-497a-b87e-148ae9c23525, 24, Finished, Available, Finished)

# %%
sales.describe().show()
geography.describe().show()
customer.describe().show()
item.describe().show()
# Out:
# StatementMeta(, 40daaad8-6c33-497a-b87e-148ae9c23525, 25, Finished, Available, Finished)
# +-------+-----------------+------------------+-----------------+------------------+------------------+------------------+------------------+------------------+
# |summary|          OrderNo|            ItemID|       CustomerId|            CityId|               Qty|             Price|              cost|   DiscountPercent|
# +-------+-----------------+------------------+-----------------+------------------+------------------+------------------+------------------+------------------+
# |  count|            30000|             30000|            30000|             30000|             30000|             30000|             30000|             30000|
# |   mean|          15000.5|           23.8998|2586.925166666667|           47.0278|1.6637666666666666|207.29673333333332|138.50326666666666|           23.0316|
# | stddev|8660.398374208884|12.967396233329536|1601.835989394005|28.381839465646248|0.6669297604688733|322.94307014840973| 199.5885266625516|12.995515799216903|
# |    min|                1|                 1|                1|                 1|                 1|                40|                36|                 1|
# |    max|            30000|                55|             6501|               100|                 3|              1733|              1299|                45|
# +-------+-----------------+------------------+-----------------+------------------+------------------+------------------+------------------+------------------+
#
# +-------+------------------+---------------+---------+
# |summary|            CityId|           City|    State|
# +-------+------------------+---------------+---------+
# |  count|               100|            100|      100|
# |   mean|              50.5|           NULL|     NULL|
# | stddev|29.011491975882016|           NULL|     NULL|
# |    min|                 1|    Albuquerque|   Alaska|
# |    max|               100|Winstonâ€“Salem|Wisconsin|
# +-------+------------------+---------------+---------+
#
# +-------+------------------+-----------------+---------------+---------+------------+
# |summary|        CustomerId|              Age|           City|    State|        Name|
# +-------+------------------+-----------------+---------------+---------+------------+
# |  count|              6138|             6138|           6138|     6138|        6138|
# |   mean|  3116.08211143695|34.43189964157706|           NULL|     NULL|        NULL|
# | stddev|1831.4120792734825|8.169102797527293|           NULL|     NULL|        NULL|
# |    min|                 1|               20|    Albuquerque|   Alaska|  Customer 1|
# |    max|              6501|               70|Winstonâ€“Salem|Wisconsin|Customer 999|
# +-------+------------------+-----------------+---------------+---------+------------+
#
# +-------+------------------+------+------------------+------------------+------------------+-------+----------+-----------+
# |summary|            ItemId|  Name|           BrandId|        CategoryId|     SubCategoryId|  Brand|  Category|SubCategory|
# +-------+------------------+------+------------------+------------------+------------------+-------+----------+-----------+
# |  count|                55|    55|                55|                55|                55|     55|        55|         55|
# |   mean|              28.0|  NULL| 7.618181818181818|2.6363636363636362|10.381818181818181|   NULL|      NULL|       NULL|
# | stddev|16.020819787597222|  NULL|3.5719634039170334|1.2526067096353786| 5.955050483633725|   NULL|      NULL|       NULL|
# |    min|                 1|Item 1|                 1|                 1|                 1|Brand 1|Category 1|  Sub Cat 1|
# |    max|                55|Item 9|                13|                 5|                21|Brand 9|Category 5|  Sub Cat 8|
# +-------+------------------+------+------------------+------------------+------------------+-------+----------+-----------+

# %%
display(sales.describe())
# Out:
# StatementMeta(, 40daaad8-6c33-497a-b87e-148ae9c23525, 26, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 1da12b64-d642-40f7-890d-ed1f26467d1e)

# %%
display(geography.summary())
# Out:
# StatementMeta(, 40daaad8-6c33-497a-b87e-148ae9c23525, 27, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 093a5eda-37c8-4b41-bedb-22a2a41b99a4)

# %%
display(sales.summary())
# Out:
# StatementMeta(, 40daaad8-6c33-497a-b87e-148ae9c23525, 28, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 2269f986-de30-4464-9597-d27ddbb325f4)

# %%
sales_filter = sales.filter(sales.CustomerId.between(59, 62))
customer_filter = customer.filter(customer.CustomerId.between(50, 60))
# Out:
# StatementMeta(, 40daaad8-6c33-497a-b87e-148ae9c23525, 30, Finished, Available, Finished)

# %%
inner_join_df = sales_filter.join(customer_filter, "CustomerId", "inner")
print("inner Join DataFrame:")
display(inner_join_df)
# Out:
# StatementMeta(, 40daaad8-6c33-497a-b87e-148ae9c23525, 31, Finished, Available, Finished)
# inner Join DataFrame:
# SynapseWidget(Synapse.DataFrame, 2e0ec14c-d2cb-451f-9a9c-34353b391701)

# %%
left_join_df = sales_filter.join(customer_filter, "CustomerId", "left")
print("left Join DataFrame:")
display(left_join_df)
# Out:
# StatementMeta(, 40daaad8-6c33-497a-b87e-148ae9c23525, 32, Finished, Available, Finished)
# left Join DataFrame:
# SynapseWidget(Synapse.DataFrame, 64e04e85-c3ac-418e-945f-ff82a600ab93)

# %%
right_join_df = sales_filter.join(customer_filter, "CustomerId", "right")
print("right Join DataFrame:")
display(right_join_df)
# Out:
# StatementMeta(, 40daaad8-6c33-497a-b87e-148ae9c23525, 33, Finished, Available, Finished)
# right Join DataFrame:
# SynapseWidget(Synapse.DataFrame, 9d0a5a41-5602-4082-846c-fea4d016b432)

# %%
full_join_df = sales_filter.join(customer_filter, "CustomerId", "full")
print("left Join DataFrame:")
display(full_join_df)
# Out:
# StatementMeta(, 40daaad8-6c33-497a-b87e-148ae9c23525, 34, Finished, Available, Finished)
# left Join DataFrame:
# SynapseWidget(Synapse.DataFrame, 81f7a6b6-b73d-4e50-bc79-d7088762db30)

# %%
anti_join_df = sales_filter.join(customer_filter, "CustomerId", "leftanti")
print("left anti Join DataFrame:")
display(anti_join_df)
# Out:
# StatementMeta(, 40daaad8-6c33-497a-b87e-148ae9c23525, 35, Finished, Available, Finished)
# left anti Join DataFrame:
# SynapseWidget(Synapse.DataFrame, 8194f89e-0150-4213-a3e5-7f6dbb462d81)

# %%
anti_join_df = customer_filter.join(sales_filter, "CustomerId", "anti")
print("left anti Join DataFrame:")
display(anti_join_df)
# Out:
# StatementMeta(, 40daaad8-6c33-497a-b87e-148ae9c23525, 36, Finished, Available, Finished)
# left anti Join DataFrame:
# SynapseWidget(Synapse.DataFrame, 3293fcf8-b003-484b-981d-96d76df1acd6)

# %%
customer = customer.drop('State', 'City')
display(customer)
# Out:
# StatementMeta(, 40daaad8-6c33-497a-b87e-148ae9c23525, 37, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 6357addc-c461-4b27-9dca-72849ae05d30)

# %%
sales_customer = sales.join(customer, "CustomerId")
sales_customer_geo = sales_customer.join(geography, "CityId")
# Perform the join operation
sales_all = sales_customer_geo.join(item, sales.ItemID == item.ItemId, "inner")

# Show the result of the join
print("Inner Join DataFrame:")
#sales_all.show()
display(sales_all)
# Out:
# StatementMeta(, 40daaad8-6c33-497a-b87e-148ae9c23525, 38, Finished, Available, Finished)
# Inner Join DataFrame:
# SynapseWidget(Synapse.DataFrame, cc32ec89-4b11-472a-98e6-e58323c7a6ba)

# %%
print(sales_all.columns)
# Out:
# StatementMeta(, 40daaad8-6c33-497a-b87e-148ae9c23525, 39, Finished, Available, Finished)
# ['CityId', 'CustomerId', 'OrderNo', 'ItemID', 'SalesDate', 'DeilveryDate', 'Qty', 'Price', 'cost', 'DiscountPercent', 'Age', 'Name', 'City', 'State', 'ItemId', 'Name', 'BrandId', 'CategoryId', 'SubCategoryId', 'Brand', 'Category', 'SubCategory']

# %%
from pyspark.sql.functions import col, expr

# Adding calculated columns
sales_all = sales_all.withColumn("Gross", col("Qty") * col("Price"))
sales_all = sales_all.withColumn("COGS", col("Qty") * col("Cost"))
sales_all = sales_all.withColumn("Discount", col("Qty") * col("Price") * col("DiscountPercent"))

# Display the DataFrame with new columns
sales_all.show()
# Out:
# StatementMeta(, 40daaad8-6c33-497a-b87e-148ae9c23525, 40, Finished, Available, Finished)
# +------+----------+-------+------+-------------------+-------------------+---+-----+----+---------------+---+-------------+-------------+----------+------+-------+-------+----------+-------------+--------+----------+-----------+-----+----+--------+
# |CityId|CustomerId|OrderNo|ItemID|          SalesDate|       DeilveryDate|Qty|Price|cost|DiscountPercent|Age|         Name|         City|     State|ItemId|   Name|BrandId|CategoryId|SubCategoryId|   Brand|  Category|SubCategory|Gross|COGS|Discount|
# +------+----------+-------+------+-------------------+-------------------+---+-----+----+---------------+---+-------------+-------------+----------+------+-------+-------+----------+-------------+--------+----------+-----------+-----+----+--------+
# |    26|      2691|  20277|    37|2020-10-03 00:00:00|2020-10-06 00:00:00|  1|  233| 172|             12| 25|Customer 2691|      Memphis| Tennessee|    37|Item 37|      3|         5|           14| Brand 3|Category 5| Sub Cat 14|  233| 172|    2796|
# |    93|      2025|  23121|    53|2020-10-02 00:00:00|2020-10-10 00:00:00|  2|   91|  77|             25| 37|Customer 2025|      Garland|     Texas|    53|Item 53|     11|         3|            3|Brand 11|Category 3|  Sub Cat 3|  182| 154|    4550|
# |    27|       882|  23186|    20|2020-10-02 00:00:00|2020-10-10 00:00:00|  1|   47|  39|              1| 30| Customer 882|Oklahoma City|  Oklahoma|    20|Item 20|     10|         2|            6|Brand 10|Category 2|  Sub Cat 6|   47|  39|      47|
# |    77|      3869|  25941|    40|2020-10-02 00:00:00|2020-10-04 00:00:00|  1|   40|  38|             13| 37|Customer 3869|   Fort Wayne|   Indiana|    40|Item 40|      6|         3|           10| Brand 6|Category 3| Sub Cat 10|   40|  38|     520|
# |    69|      1070|  26619|    29|2020-10-02 00:00:00|2020-10-07 00:00:00|  2|   91|  77|              2| 35|Customer 1070|        Plano|     Texas|    29|Item 29|     13|         3|           16|Brand 13|Category 3| Sub Cat 16|  182| 154|     364|
# |    97|      1763|  29171|    49|2020-10-02 00:00:00|2020-10-03 00:00:00|  2|   97|  67|             44| 28|Customer 1763|        Boise|     Idaho|    49|Item 49|      2|         4|           19| Brand 2|Category 4| Sub Cat 19|  194| 134|    8536|
# |    63|      5083|  29189|    17|2020-10-02 00:00:00|2020-10-05 00:00:00|  2|   47|  39|             45| 26|Customer 5083|   Saint Paul| Minnesota|    17|Item 17|      1|         1|           21| Brand 1|Category 1| Sub Cat 21|   94|  78|    4230|
# |    72|      4356|  29191|    39|2020-10-02 00:00:00|2020-10-08 00:00:00|  2|   67|  53|             14| 27|Customer 4356|       Irvine|California|    39|Item 39|      1|         4|            2| Brand 1|Category 4|  Sub Cat 2|  134| 106|    1876|
# +------+----------+-------+------+-------------------+-------------------+---+-----+----+---------------+---+-------------+-------------+----------+------+-------+-------+----------+-------------+--------+----------+-----------+-----+----+--------+
# only showing top 20 rows

# %%
display(sales_all)
# Out:
# StatementMeta(, 40daaad8-6c33-497a-b87e-148ae9c23525, 41, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 5afd0c23-1baa-4de9-8e02-c4acbcc1766e)

# %%
# Grouping by City and State
grouped_city_state = sales_all.groupBy("City", "State").agg(
    expr("sum(Gross) as TotalGross"),
    expr("sum(COGS) as TotalCOGS"),
    expr("sum(Discount) as TotalDiscount")
)
display(grouped_city_state)
# Out:
# StatementMeta(, 40daaad8-6c33-497a-b87e-148ae9c23525, 42, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 9176934f-0d96-4458-b5a2-115444dc3bdf)

# %%
sales.write.format("delta").saveAsTable("sales_delta")
# Out:
# StatementMeta(, 40daaad8-6c33-497a-b87e-148ae9c23525, 43, Finished, Available, Finished)

# %%
geography.write.format("delta").mode("overwrite").save("Tables/dbo/geography")
# Out:
# StatementMeta(, 40daaad8-6c33-497a-b87e-148ae9c23525, 44, Finished, Available, Finished)

# %%
# %%sql
#
# SELECT * FROM Lake01.dbo.sales_delta LIMIT 1000
# Out:
# StatementMeta(, 40daaad8-6c33-497a-b87e-148ae9c23525, 45, Finished, Available, Finished)
# <Spark SQL result set with 1000 rows and 10 fields>
